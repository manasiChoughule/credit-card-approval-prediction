# %% [markdown]
# # Predicting the Credit Card Approval

# %% [markdown]
# ### Importing data and required packages

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

from scipy.stats import iqr
from sklearn.base import BaseEstimator, TransformerMixin

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler, OrdinalEncoder

from imblearn.over_sampling import SMOTE

# %% [markdown]
# ### Import the CSV Data to Pandas DataFrame

# %%
application_record = pd.read_csv("data//application_record_transformed.csv")

# %% [markdown]
# ### Show Top 5 Records

# %%
application_record.head()
# Out:
#    Unnamed: 0       ID gender has_a_car has_a_property  no_of_children  \
# 0           0  5008804      M         Y              Y               0
# 1           1  5008805      M         Y              Y               0
# 2           2  5008806      M         Y              Y               0
# 3           3  5008808      F         N              Y               0
# 4           4  5008809      F         N              Y               0
#
#      income     employment_status                education_level  \
# 0  427500.0               Working               Higher education
# 1  427500.0               Working               Higher education
# 2  112500.0               Working  Secondary / secondary special
# 3  270000.0  Commercial associate  Secondary / secondary special
# 4  270000.0  Commercial associate  Secondary / secondary special
#
#          marital_status            housing   age  employment_length  \
# 0        Civil marriage   Rented apartment  33.0              12.44
# 1        Civil marriage   Rented apartment  33.0              12.44
# 2               Married  House / apartment  59.0               3.11
# 3  Single / not married  House / apartment  52.0               8.36
# 4  Single / not married  House / apartment  52.0               8.36
#
#    has_a_mobile  has_a_workphone  has_a_phone  has_an_email       job_title  \
# 0             1                1            0             0         Unknown
# 1             1                1            0             0         Unknown
# 2             1                0            0             0  Security staff
# 3             1                0            1             1     Sales staff
# 4             1                0            1             1     Sales staff
#
#    family_member_count  is_risky_customer
# 0                  2.0                  0
# 1                  2.0                  0
# 2                  2.0                  0
# 3                  1.0                  0
# 4                  1.0                  0

# %%
application_record = application_record.drop('Unnamed: 0', axis = 'columns')

# %%
application_record.head()
# Out:
#         ID gender has_a_car has_a_property  no_of_children    income  \
# 0  5008804      M         Y              Y               0  427500.0
# 1  5008805      M         Y              Y               0  427500.0
# 2  5008806      M         Y              Y               0  112500.0
# 3  5008808      F         N              Y               0  270000.0
# 4  5008809      F         N              Y               0  270000.0
#
#       employment_status                education_level        marital_status  \
# 0               Working               Higher education        Civil marriage
# 1               Working               Higher education        Civil marriage
# 2               Working  Secondary / secondary special               Married
# 3  Commercial associate  Secondary / secondary special  Single / not married
# 4  Commercial associate  Secondary / secondary special  Single / not married
#
#              housing   age  employment_length  has_a_mobile  has_a_workphone  \
# 0   Rented apartment  33.0              12.44             1                1
# 1   Rented apartment  33.0              12.44             1                1
# 2  House / apartment  59.0               3.11             1                0
# 3  House / apartment  52.0               8.36             1                0
# 4  House / apartment  52.0               8.36             1                0
#
#    has_a_phone  has_an_email       job_title  family_member_count  \
# 0            0             0         Unknown                  2.0
# 1            0             0         Unknown                  2.0
# 2            0             0  Security staff                  2.0
# 3            1             1     Sales staff                  1.0
# 4            1             1     Sales staff                  1.0
#
#    is_risky_customer
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0

# %% [markdown]
# ### Data Preprosessing

# %% [markdown]
# The feature ID does not hold significant importance. We would drop this in our analysis.

# %% [markdown]
# Gender has M and F values. We would perform one hot encoding for this.

# %% [markdown]
# We would also drop the feature, no_of_childern as it is highly correlated to family_member_count.
